# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_excel('instagram_hashtag_data_f.xlsx')
data
# Out:
#                                              id  type  \
# 0      https://www.instagram.com/p/BVwh5IYAXyJ/     1
# 1      https://www.instagram.com/p/BYgQOMJFY36/     0
# 2      https://www.instagram.com/p/BbvQarblI8-/     1
# 3      https://www.instagram.com/p/Bb8V2uEhFiF/     0
# 4      https://www.instagram.com/p/BZd39qTnDU0/     1
# ...                                         ...   ...
# 10361  https://www.instagram.com/p/BcMVdbUHMyg/     0
# 10362  https://www.instagram.com/p/Ba3Nj_QH90T/     0
# 10363  https://www.instagram.com/p/BbeCcYzF4kp/     1
# 10364  https://www.instagram.com/p/BbMStBTBHAi/     1
# 10365  https://www.instagram.com/p/BaTTU_hHNMn/     0
#
#                                                     word
# 0                                         경리단길카페, 맛스타그램,
# 1      가을신상, 가을한정판, 가을가을해, 데일리백, 주말데이트, 주말에뭐입지, 한남동맛집...
# 2                                  이태원, 브런치, 데이트, 럽스타그램,
# 3        앤드하리, 앤드하리한남, 한남동카페, 한강진카페, 이태원카페, 강화도카페, 강화카페,
# ...

# %%
df = data.drop('id',axis=1)
df
# Out:
#        type                                               word
# 0         1                                     경리단길카페, 맛스타그램,
# 1         0  가을신상, 가을한정판, 가을가을해, 데일리백, 주말데이트, 주말에뭐입지, 한남동맛집...
# 2         1                              이태원, 브런치, 데이트, 럽스타그램,
# 3         0    앤드하리, 앤드하리한남, 한남동카페, 한강진카페, 이태원카페, 강화도카페, 강화카페,
# 4         1                                    사유, 이태원, 이태원카페,
# ...     ...                                                ...
# 10361     0  성산일출봉\t, 해운대맛집\t, 환승\t, 신천\t, 시험기간, 11자복근\t, 스...
# 10362     0  jw메리어트호텔, 거창까막국수, 동대문맛집, 롯데백화점, 대구맛집, 서울맛집, 대전...
# 10363     1  먹스타그램, 한남동맛집, 나들이, 고추장불백, 맛있다, iphone7plus, pi...
# 10364     1  오랜만에, 한남동, 한남살롱, 맥주한잔, 양꼬치, 양꼬치맛집, 양고기, 홈메이드, ...
# 10365     0  Repost, 이태원, 우사단길, 우사단데이, 서울에서제일작은축제, 남자식당, 축제...
#
# [10366 rows x 2 columns]

# %%
re.sub('\<.*\>', '', df.at[10361, 'word'])
# Out:
# '성산일출봉\\t, 해운대맛집\\t, 환승\\t, 신천\\t, 시험기간, 11자복근\\t, 스노우\\t, 임학사거리, , 입맛\\t, 심심해\\t, 대화\\t, 삼진\\t, 구영해변,'

# %%
re.sub('[\\t]', '', df.at[10361, 'word'])
# Out:
# '성산일출봉\\t, 해운대맛집\\t, 환승\\t, 신천\\t, 시험기간, 11자복근\\t, 스노우\\t, 임학사거리, <U+00A0>\\t, 여튼\\t, 직장, 파도리해변\\t, 수제맥주\\t, 선팔100\\t, 초록, <U+00A0>\\t, 대학원, 천안맘\\t, 이태원카페\\t, 재밋다\\t, 사천해변\\t, 임학사거리, <U+00A0>, 입맛\\t, 심심해\\t, 대화\\t, 삼진\\t, 구영해변,'

# %%
df['word']
# Out:
# 0                                           경리단길카페, 맛스타그램,
# 1        가을신상, 가을한정판, 가을가을해, 데일리백, 주말데이트, 주말에뭐입지, 한남동맛집...
# 2                                    이태원, 브런치, 데이트, 럽스타그램,
# 3          앤드하리, 앤드하리한남, 한남동카페, 한강진카페, 이태원카페, 강화도카페, 강화카페,
# 4                                          사유, 이태원, 이태원카페,
#                                ...
# 10361    성산일출봉\t, 해운대맛집\t, 환승\t, 신천\t, 시험기간, 11자복근\t, 스...
# 10362    jw메리어트호텔, 거창까막국수, 동대문맛집, 롯데백화점, 대구맛집, 서울맛집, 대전...
# 10363    먹스타그램, 한남동맛집, 나들이, 고추장불백, 맛있다, iphone7plus, pi...
# 10364    오랜만에, 한남동, 한남살롱, 맥주한잔, 양꼬치, 양꼬치맛집, 양고기, 홈메이드, ...
# 10365    Repost, 이태원, 우사단길, 우사단데이, 서울에서제일작은축제, 남자식당, 축제...
# Name: word, Length: 10366, dtype: object

# %%
df['word'] = df['word'].apply(lambda x : re.sub("<[a-zA-Z0-9]+>",'', str(x))) 
df['word'] = df['word'].apply(lambda x: x.replace('\\t',''))

# %%
# df_['word'].apply(lambda x : re.sub("[^가-힣a-zA-Z0-9, ]+",'', str(x)))
# Out:
# 0                                           경리단길카페, 맛스타그램,
# 1        가을신상, 가을한정판, 가을가을해, 데일리백, 주말데이트, 주말에뭐입지, 한남동맛집...
# 2                                    이태원, 브런치, 데이트, 럽스타그램,
# 3          앤드하리, 앤드하리한남, 한남동카페, 한강진카페, 이태원카페, 강화도카페, 강화카페,
# 4                                          사유, 이태원, 이태원카페,
#                                ...
# 10361    성산일출봉t, 해운대맛집t, 환승t, 신천t, 시험기간, 11자복근t, 스노우t, ...
# 10362    jw메리어트호텔, 거창까막국수, 동대문맛집, 롯데백화점, 대구맛집, 서울맛집, 대전...
# 10363    먹스타그램, 한남동맛집, 나들이, 고추장불백, 맛있다, iphone7plus, pi...
# 10364    오랜만에, 한남동, 한남살롱, 맥주한잔, 양꼬치, 양꼬치맛집, 양고기, 홈메이드, ...
# 10365    Repost, 이태원, 우사단길, 우사단데이, 서울에서제일작은축제, 남자식당, 축제...
# Name: word, Length: 10366, dtype: object

# %%
# df_['word'].apply(lambda x : re.sub("[가-히]t",'', str(x)))
# Out:
# 0                                           경리단길카페, 맛스타그램,
# 1        가을신상, 가을한정판, 가을가을해, 데일리백, 주말데이트, 주말에뭐입지, 한남동맛집...
# 2                                    이태원, 브런치, 데이트, 럽스타그램,
# 3          앤드하리, 앤드하리한남, 한남동카페, 한강진카페, 이태원카페, 강화도카페, 강화카페,
# 4                                          사유, 이태원, 이태원카페,
#                                ...
# 10361    성산일출봉\t, 해운대맛집\t, 환승\t, 신천\t, 시험기간, 11자복근\t, 스...
# 10362    jw메리어트호텔, 거창까막국수, 동대문맛집, 롯데백화점, 대구맛집, 서울맛집, 대전...
# 10363    먹스타그램, 한남동맛집, 나들이, 고추장불백, 맛있다, iphone7plus, pi...
# 10364    오랜만에, 한남동, 한남살롱, 맥주한잔, 양꼬치, 양꼬치맛집, 양고기, 홈메이드, ...
# 10365    Repost, 이태원, 우사단길, 우사단데이, 서울에서제일작은축제, 남자식당, 축제...
# Name: word, Length: 10366, dtype: object

# %%
# df_['word'].apply(lambda x : re.sub("<[a-zA-Z0-9]+>",'', str(x)))
# Out:
# 0                                           경리단길카페, 맛스타그램,
# 1        가을신상, 가을한정판, 가을가을해, 데일리백, 주말데이트, 주말에뭐입지, 한남동맛집...
# 2                                    이태원, 브런치, 데이트, 럽스타그램,
# 3          앤드하리, 앤드하리한남, 한남동카페, 한강진카페, 이태원카페, 강화도카페, 강화카페,
# 4                                          사유, 이태원, 이태원카페,
#                                ...
# 10361    성산일출봉\t, 해운대맛집\t, 환승\t, 신천\t, 시험기간, 11자복근\t, 스...
# 10362    jw메리어트호텔, 거창까막국수, 동대문맛집, 롯데백화점, 대구맛집, 서울맛집, 대전...
# 10363    먹스타그램, 한남동맛집, 나들이, 고추장불백, 맛있다, iphone7plus, pi...
# 10364    오랜만에, 한남동, 한남살롱, 맥주한잔, 양꼬치, 양꼬치맛집, 양고기, 홈메이드, ...
# 10365    Repost, 이태원, 우사단길, 우사단데이, 서울에서제일작은축제, 남자식당, 축제...
# Name: word, Length: 10366, dtype: object

# %%
#  df_["word"].apply(lambda x : re.sub("\<.*\>|\s-\s.*",'', str(x)))
# Out:
# 0                                           경리단길카페, 맛스타그램,
# 1        가을신상, 가을한정판, 가을가을해, 데일리백, 주말데이트, 주말에뭐입지, 한남동맛집...
# 2                                    이태원, 브런치, 데이트, 럽스타그램,
# 3          앤드하리, 앤드하리한남, 한남동카페, 한강진카페, 이태원카페, 강화도카페, 강화카페,
# 4                                          사유, 이태원, 이태원카페,
#                                ...
# 10361    성산일출봉\t, 해운대맛집\t, 환승\t, 신천\t, 시험기간, 11자복근\t, 스...
# 10362    jw메리어트호텔, 거창까막국수, 동대문맛집, 롯데백화점, 대구맛집, 서울맛집, 대전...
# 10363    먹스타그램, 한남동맛집, 나들이, 고추장불백, 맛있다, iphone7plus, pi...
# 10364    오랜만에, 한남동, 한남살롱, 맥주한잔, 양꼬치, 양꼬치맛집, 양고기, 홈메이드, ...
# 10365    Repost, 이태원, 우사단길, 우사단데이, 서울에서제일작은축제, 남자식당, 축제...
# Name: word, Length: 10366, dtype: object

# %%
# df_.at[10361, 'word']
# Out:
# '성산일출봉\\t, 해운대맛집\\t, 환승\\t, 신천\\t, 시험기간, 11자복근\\t, 스노우\\t, 임학사거리, <U+00A0>\\t, 여튼\\t, 직장, 파도리해변\\t, 수제맥주\\t, 선팔100\\t, 초록, <U+00A0>\\t, 대학원, 천안맘\\t, 이태원카페\\t, 재밋다\\t, 사천해변\\t, 임학사거리, <U+00A0>, 입맛\\t, 심심해\\t, 대화\\t, 삼진\\t, 구영해변,'

# %%
# df["word"] = df["word"].apply(lambda x : re.sub("\<.*\>|\s-\s.*",'', str(x)))
# df["word"] = df["word"].apply(lambda x : re.sub('[^\w\s]','', str(x)))

# %%
df
# Out:
#        type                                               word
# 0         1                                       경리단길카페 맛스타그램
# 1         0  가을신상 가을한정판 가을가을해 데일리백 주말데이트 주말에뭐입지 한남동맛집 clutc...
# 2         1                                  이태원 브런치 데이트 럽스타그램
# 3         0           앤드하리 앤드하리한남 한남동카페 한강진카페 이태원카페 강화도카페 강화카페
# 4         1                                       사유 이태원 이태원카페
# ...     ...                                                ...
# 10361     0  성산일출봉t 해운대맛집t 환승t 신천t 시험기간 11자복근t 스노우t 임학사거리  ...
# 10362     0  jw메리어트호텔 거창까막국수 동대문맛집 롯데백화점 대구맛집 서울맛집 대전맛집 광주맛...
# 10363     1  먹스타그램 한남동맛집 나들이 고추장불백 맛있다 iphone7plus picture ...
# 10364     1  오랜만에 한남동 한남살롱 맥주한잔 양꼬치 양꼬치맛집 양고기 홈메이드 주석잔 MY 맥...
# 10365     0  Repost 이태원 우사단길 우사단데이 서울에서제일작은축제 남자식당 축제 마을파티 ...
#
# [10366 rows x 2 columns]

# %%
x = df.word
y = df.type

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2, random_state=1234)

# %%
train_X.shape
# Out:
# (8292,)

# %%
test_X.shape
# Out:
# (2074,)

# %%
train_y.shape
# Out:
# 3397     1
# 10323    1
# 6688     1
# 3171     1
# 6027     1
#         ..
# 664      1
# 7540     1
# 7221     0
# 1318     1
# 8915     1
# Name: type, Length: 8292, dtype: int64

# %%
test_y.shape
# Out:
# 5933    0
# 3992    0
# 741     1
# 1621    0
# 582     1
#        ..
# 6054    1
# 7193    1
# 632     1
# 5512    1
# 5944    0
# Name: type, Length: 2074, dtype: int64

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
token = Tokenizer()
token.fit_on_texts(X_train)
X_train_encode = token.texts_to_sequences(X_train)
X_train_encode
# Out:
# [[46, 73, 72, 22, 45, 24, 86, 108, 82, 11, 114, 64, 53, 78, 7, 3, 66, 99, 123],
#  [388,
#   22,
#   17,
#   3,
#   268,
#   258,
#   15,
#   470,
#   292,
#   89,
#   347,
#   93,
#   356,
#   9,
#   407,
#   389,
#   199,
#   91,
#   803,
#   269],
#  [7501,
#   17,
#   2941,
#   336,
#   25,
#   341,
#   1031,
#   4862,
#   7502,
#   500,
#   1,
#   5,
#   1,
#   2,
#   13,
#   1,
#   14,
#   1,
#   4,
#   1,
#   126,
#   1,
#   5,
#   1,
#   2,
#   1,
#   4,
#   1,
#   84,
#   1,
#   49,
#   1,
#   79,
#   1,
#   5,
#   1,
#   2,
#   13,
#   1,
#   14,
#   1,
#   4,
#   1,
#   126,
#   1,
#   5,
#   1,
#   2,
#   1,
#   4,
#   1,
#   84,
#   1,
#   49,
#   1,
#   79,
#   1,
#   5,
#   1,
#   2,
#   13,
#   1,
#   14,
#   1,
#   4,
#   1,
#   126,
#   1,
#   5,
#   1,
#   2,
#   1,
#   4,
#   1,
#   84,
#   1,
#   49,
#   1,
#   79,
#   1538,
#   7503,
#   1,
#   5,
#   1,
#   2,
#   13,
#   1,
#   14,
#   1,
#   4,
#   1,
#   2,
#   1,
#   5,
#   1,
#   2,
#   1,
#   4,
#   1,
# ...

# %%
word_to_index = token.word_index
word_to_index
# Out:
# {'u': 1,
#  '3e64': 2,
#  '이태원': 3,
#  '623c': 4,
#  '653c': 5,
#  '00a0': 6,
#  '이태원맛집': 7,
#  '먹스타그램': 8,
#  '우사단길': 9,
#  '경리단길': 10,
#  '이태원카페': 11,
#  '일상': 12,
#  '愼': 13,
#  '3e30': 14,
#  '맛스타그램': 15,
#  '데일리': 16,
#  '한남동': 17,
#  '한남동맛집': 18,
#  '경리단길카페': 19,
#  '해방촌맛집': 20,
#  '해방촌': 21,
#  '맛집': 22,
#  '맞팔': 23,
#  'itaewon': 24,
#  '한남동카페': 25,
#  '경리단길맛집': 26,
#  '먹방': 27,
#  '카페': 28,
#  '3e63': 29,
#  '커피': 30,
#  '디저트': 31,
#  '소통': 32,
#  '카페스타그램': 33,
#  '셀카': 34,
#  '경리단': 35,
#  'cafe': 36,
#  '좋아요': 37,
#  'daily': 38,
#  '커피스타그램': 39,
#  '셀피': 40,
#  '럽스타그램': 41,
#  '셀스타그램': 42,
#  '해방촌카페': 43,
#  '383c': 44,
#  '데이트': 45,
#  '이태원역': 46,
#  '오늘뭐먹지': 47,
#  '인테리어': 48,
#  '393c': 49,
#  '사진': 50,
#  '불금': 51,
#  '가을': 52,
#  '이태원술집': 53,
#  '힐링': 54,
#  '얼스타그램': 55,
#  'coffee': 56,
#  '온더테이블': 57,
#  '우사단로': 58,
#  '금요일': 59,
#  '디저트스타그램': 60,
#  '푸딩': 61,
#  '퇴근길': 62,
#  '퇴근': 63,
#  '이태원데이트': 64,
#  '아이폰7': 65,
#  '이태원핫플': 66,
#  'seoul': 67,
#  '후식': 68,
# ...

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
pad_x = pad_sequences(X_train_encode)
pad_x
# Out:
# (8292, 286)

# %%
test_X_encode = token.texts_to_sequences(test_X)
X_test_pad = pad_sequences(test_X_encode)

# %%
from tensorflow.keras.layers import SimpleRNN, Embedding, Dense
from tensorflow.keras.models import Sequential

# %%
vocab_size = len(word_to_index) + 1

# %%
model = Sequential()
model.add(Embedding(vocab_size, 32)) # 임베딩 벡터의 차원은 32
model.add(SimpleRNN(32)) # RNN 셀의 hidden_size는 32
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_3 (Embedding)     (None, None, 32)          752192
#
#  simple_rnn_3 (SimpleRNN)    (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# ...
# Total params: 754,305
# Trainable params: 754,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(pad_x, train_y, epochs=4, batch_size=64, validation_split=0.2)

# %%
model = Sequential()
model.add(Embedding(vocab_size, 32)) # 임베딩 벡터의 차원은 32
model.add(SimpleRNN(32)) # RNN 셀의 hidden_size는 32
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(pad_x, train_y, epochs=20, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/20
# 104/104 [==============================] - 47s 443ms/step - loss: 0.5617 - acc: 0.7065 - val_loss: 0.4725 - val_acc: 0.7854
# Epoch 2/20
# 104/104 [==============================] - 44s 424ms/step - loss: 0.3735 - acc: 0.8444 - val_loss: 0.3867 - val_acc: 0.8366
# Epoch 3/20
# 104/104 [==============================] - 46s 440ms/step - loss: 0.2733 - acc: 0.8963 - val_loss: 0.3816 - val_acc: 0.8330
# Epoch 4/20
# 104/104 [==============================] - 46s 441ms/step - loss: 0.1898 - acc: 0.9335 - val_loss: 0.3451 - val_acc: 0.8590
# Epoch 5/20
# 104/104 [==============================] - 46s 438ms/step - loss: 0.1272 - acc: 0.9591 - val_loss: 0.3537 - val_acc: 0.8608
# Epoch 6/20
# 104/104 [==============================] - 45s 430ms/step - loss: 0.0947 - acc: 0.9715 - val_loss: 0.3758 - val_acc: 0.8596
# Epoch 7/20
# 104/104 [==============================] - 45s 431ms/step - loss: 0.0781 - acc: 0.9756 - val_loss: 0.4088 - val_acc: 0.8397
# Epoch 8/20
# ...

# %%
print("\n 테스트 정확도: %.4f" % (model.evaluate(X_test_pad, y_test)[1]))
# Out:
# 65/65 [==============================] - 1s 22ms/step - loss: 0.5676 - acc: 0.7975
#
#  테스트 정확도: 0.7975

# %%
import json

# %%
a = json.dumps(list(df['word']))

# %%
a = list(df['word'])
a
# Out:
# ['경리단길카페, 맛스타그램,',
#  '가을신상, 가을한정판, 가을가을해, 데일리백, 주말데이트, 주말에뭐입지, 한남동맛집, clutch, dailybag, s, <U+0113>rigraphie, lovelylook, like4like, follow4follow, lovely, chic, fashon,',
#  '이태원, 브런치, 데이트, 럽스타그램,',
#  '앤드하리, 앤드하리한남, 한남동카페, 한강진카페, 이태원카페, 강화도카페, 강화카페,',
#  '사유, 이태원, 이태원카페,',
#  '초간단요리, <U+653C>, <U+3E64>, 愼, <U+3E30>, <U+623C>, <U+3E63>, <U+653C>, <U+3E64>, <U+623C>, <U+3E64>, <U+623C>, <U+3E34>, 토마토비비큐, 야끼소바, 우사단로, 우사단길, 이태원맛집, 이태원밥집, 자취생밥상, 자취생요리, 초간단요리법, 초간단요리그램, 혼밥러, 혼밥족, 간편요리,',
#  '보광헌옷, BoGwangdong, Vintage, UsedThings, ThriftStore, 보광동, 한남동, 이태원, 우사단로, 우사단길..DM,',
#  '더백푸드트럭.맛있는건, 버거가갑, 예약필수, 수제버거,',
#  '경리단길, 더베이커스테이블.1., 경리단길카페, 경리단길브런치, 빵스타그램,',
#  '이태원맛집, 이태원술집, 이태원짜박이, 경리단길맛집, 녹사평역맛집,',
#  '한와담, 와인콜키지, 한와담블랙, 데판야끼, 관자, 냠냠, yammyyammy, 생일저녁은역시한우지ㅋㅋㅋ, 배부르게냠냠, 한남동맛집, foodpic, foodporn, latergram, awesome, HBD, 20171121,',
#  '샌드위치가게, 플랫아이언, 플로리스트, 선물, 스텝밀, 샌드위치, 보석길, 회나무길, 경리단길, 이태원,',
# ...

# %%
df[df['type']==1].iat[17,1]
# Out:
# '튜브라떼, 솔티드카라멜라떼, 페리로스터즈, 경리단길, , <U+653C>, <U+3E64>, 愼, <U+3E30>, <U+623C>, <U+3E63>, <U+653C>, <U+3E64>, <U+623C>, <U+3E64>, 愼, <U+3E39>, daily, 경리단길카페, 데일리그램, 카페추천, 이태원, 으니그램, cafe,'

# %%
df[df['type']==0].at[10361,'word']
# Out:
# '성산일출봉\\t, 해운대맛집\\t, 환승\\t, 신천\\t, 시험기간, 11자복근\\t, 스노우\\t, 임학사거리, <U+00A0>\\t, 여튼\\t, 직장, 파도리해변\\t, 수제맥주\\t, 선팔100\\t, 초록, <U+00A0>\\t, 대학원, 천안맘\\t, 이태원카페\\t, 재밋다\\t, 사천해변\\t, 임학사거리, <U+00A0>, 입맛\\t, 심심해\\t, 대화\\t, 삼진\\t, 구영해변,'

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB # 다항분포 나이브 베이즈 모델
from sklearn.metrics import accuracy_score #정확도 계산

# %%
dtmvector = CountVectorizer()
X_train_dtm = dtmvector.fit_transform(train_X)
print(X_train_dtm.shape)
# Out:
# (8292, 23223)

# %%
tfidf_transformer = TfidfTransformer()
tfidfv = tfidf_transformer.fit_transform(X_train_dtm)
print(tfidfv.shape)
# Out:
# (8292, 23223)

# %%
mod = MultinomialNB()
mod.fit(tfidfv, train_y)
# Out:
# MultinomialNB()

# %%
test_X = dtmvector.transform(test_X)
tfidfv_test = tfidf_transformer.transform(test_X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 test_X = dtmvector.transform(test_X)
#       2 tfidfv_test_1 = tfidf_transformer.transform(test_X)
#
# File ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1379, in CountVectorizer.transform(self, raw_documents)
#    1376 self._check_vocabulary()
#    1378 # use the same matrix-building strategy as fit_transform
# -> 1379 _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#    1380 if self.binary:
#    1381     X.data.fill(1)
#
# File ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1201, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1199 for doc in raw_documents:
#    1200     feature_counter = {}
# -> 1201     for feature in analyze(doc):
#    1202         try:
#    1203             feature_idx = vocabulary[feature]
#
# ...

# %%
predicted = mod.predict(tfidfv_test)

# %%
print("정확도:", accuracy_score(test_y, predicted))
# Out:
# 정확도: 0.8360655737704918

# %%
mod = MultinomialNB()
mod.fit(X_train_dtm, train_y)
# Out:
# MultinomialNB()

# %%
predicted = mod.predict(test_X)

# %%
print("정확도:", accuracy_score(test_y, predicted))
# Out:
# 정확도: 0.8379942140790743

# %%
from sklearn.metrics import f1_score

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 f1_score(accuracy_score(test_y, predicted))
#
# TypeError: f1_score() missing 1 required positional argument: 'y_pred'
